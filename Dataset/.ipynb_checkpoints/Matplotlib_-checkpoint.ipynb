# %%
import matplotlib.pyplot as plt
x=["python","java","C++"]
y=[84,65,75]
c=["g","r","b"]
plt.xlabel("language")
plt.ylabel("demand score")
plt.title("Bar Plot",fontsize=15)
plt.bar(x,y,width=0.4,color=c,edgecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)   # 1000 random data points

plt.hist(data, bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram plot',fontsize=15)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
marks=[80,90,65,88,36,98]
student=["Hiamsnshu","Ansh","Satyram","Sandhaya","Ayush","Sneha"]
c=["r","y","b","g","r","b"]
plt.bar(marks,student,color=c,edgecolor='black')
plt.xlabel("Mark")
plt.ylabel("Student")
plt.title(" Bar Result",fontsize=15)
plt.legend("Result")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[10,11,1,13,110,15,16,17,18]
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend("Sales")
plt.title("Simple line plot",fontsize=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,color='hotpink')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend("Sales")
plt.title("Scatter Plot",fontsize=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.plot(x,y,color='hotpink')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend("Sales")
plt.title("line Plot",fontsize=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#day one, the age and speed of 13 cars
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,label="B group",edgecolor='black')
#day two, the age and speed of 15 cars
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,label="A group")
plt.colorbar()
plt.title("Multiple scatter",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
marks=[95,65,78,56,35]
subject=['Science','Hindi','Sanskriti','Urdu','Tamil']
plt.pie(marks,labels=subject,autopct='%0.1f%%')
plt.title("Pie Plot",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


x=np.random.rand(100)
y=np.random.rand(100)
z=np.random.rand(100)

colors=np.random.rand(100)
# 3d scatter plot

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

ax.scatter(x,y,z,c=colors,marker='+',s=50,cmap='rainbow')

ax.set_title(" Scatter 3d plot",fontsize=15)
ax.set_xlabel('x -axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


x=np.random.rand(10)
y=np.random.rand(10)
z=np.random.rand(10)

colors=np.random.rand(10)
# 3d scatter plot

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

ax.scatter(x,y,z,c=colors,marker='+',s=50,cmap='rainbow')
ax.plot(x,y,z,color='red')

ax.set_title("line  3d plot",fontsize=15)
ax.set_xlabel('x -axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.rand(20)
y=np.random.rand(20)
X,Y=np.meshgrid(x,y)
Z=np.random.rand(20,20)

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
p=ax.plot_surface(X,Y,Z,cmap='rainbow')
ax.set_title("Surface 3d plot")
ax.set_xlabel('x -axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.colorbar(p)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.rand(100)
y=np.random.rand(100)
X,Y=np.meshgrid(x,y)
Z=np.sin(X)+np.cos(Y)

fig=plt.figure()
ax=fig.add_subplot()
p=ax.contourf(X,Y,Z,cmap='viridis')
ax.set_title("Contour plot ",fontsize=15)
plt.colorbar(p)
plt.show()
